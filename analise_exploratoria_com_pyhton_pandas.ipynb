# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiago-Alvees/DesaProcessando-e-Transformando-Dados-com-Power-BI/blob/main/analise_exploratoria_com_pyhton_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando as bibliotecas pandas, e matplotlib para customizar os gráficos.
import pandas as pd
import matplotlib.pyplot as plt

# %%
#fazendo uploud do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-c8b82223-1b93-4592-83d4-d974713675cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8b82223-1b93-4592-83d4-d974713675cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#criando o datadrame
df = pd.read_csv("products.csv")

# %%
#teste para vizualizar as 5 primeiras linhas
df.head()
# Out:
#    ProductID ProductNumber                ProductName            ModelName  \
# 0        680    FR-R92B-58  HL Road Frame - Black, 58        HL Road Frame
# 1        706    FR-R92R-58    HL Road Frame - Red, 58        HL Road Frame
# 2        707     HL-U509-R      Sport-100 Helmet, Red            Sport-100
# 3        708       HL-U509    Sport-100 Helmet, Black            Sport-100
# 4        709     SO-B909-M     Mountain Bike Socks, M  Mountain Bike Socks
#
#    MakeFlag  StandardCost  ListPrice  SubCategoryID
# 0         1     1059.3100    1431.50             14
# 1         1     1059.3100    1431.50             14
# 2         0       13.0863      34.99             31
# 3         0       13.0863      34.99             31
# 4         0        3.3963       9.50             23

# %%
#renomenado as colunas
df.rename(columns={"ProductID":"IdProduto","ProductNumber":"NomeID","ProductName":"Nome do Produto","ModelName":"Modelo","MakeFlag":"Enviados","StandardCost":"Custo","ListPrice":"Preço de venda"})
# Out:
#      IdProduto      NomeID            Nome do Produto               Modelo  \
# 0          680  FR-R92B-58  HL Road Frame - Black, 58        HL Road Frame
# 1          706  FR-R92R-58    HL Road Frame - Red, 58        HL Road Frame
# 2          707   HL-U509-R      Sport-100 Helmet, Red            Sport-100
# 3          708     HL-U509    Sport-100 Helmet, Black            Sport-100
# 4          709   SO-B909-M     Mountain Bike Socks, M  Mountain Bike Socks
# ..         ...         ...                        ...                  ...
# 290        995     BB-8107          ML Bottom Bracket    ML Bottom Bracket
# 291        996     BB-9108          HL Bottom Bracket    HL Bottom Bracket
# 292        997  BK-R19B-44         Road-750 Black, 44             Road-750
# 293        998  BK-R19B-48         Road-750 Black, 48             Road-750
# 294        999  BK-R19B-52         Road-750 Black, 52             Road-750
#
#      Enviados      Custo  Preço de venda  SubCategoryID
# ...

# %%
#como saber o total de linhas e colunas do nosso dataframe(conjunto de dados)
df.shape
# Out:
# (295, 8)

# %%
#como retornar apenas os nomes das colunas
df.columns
# Out:
# Index(['ProductID', 'ProductNumber', 'ProductName', 'ModelName', 'MakeFlag',
#        'StandardCost', 'ListPrice', 'SubCategoryID'],
#       dtype='object')

# %%
#como saber o tipo de dado em cada coluna
df.dtypes
# Out:
# ProductID          int64
# ProductNumber     object
# ProductName       object
# ModelName         object
# MakeFlag           int64
# StandardCost     float64
# ListPrice        float64
# SubCategoryID      int64
# dtype: object

# %%
#como retornar apenas as ultimas linhas
df.tail(10)
# Out:
#      ProductID ProductNumber             ProductName          ModelName  \
# 285        990    BK-M18B-42  Mountain-500 Black, 42       Mountain-500
# 286        991    BK-M18B-44  Mountain-500 Black, 44       Mountain-500
# 287        992    BK-M18B-48  Mountain-500 Black, 48       Mountain-500
# 288        993    BK-M18B-52  Mountain-500 Black, 52       Mountain-500
# 289        994       BB-7421       LL Bottom Bracket  LL Bottom Bracket
# 290        995       BB-8107       ML Bottom Bracket  ML Bottom Bracket
# 291        996       BB-9108       HL Bottom Bracket  HL Bottom Bracket
# 292        997    BK-R19B-44      Road-750 Black, 44           Road-750
# 293        998    BK-R19B-48      Road-750 Black, 48           Road-750
# 294        999    BK-R19B-52      Road-750 Black, 52           Road-750
#
#      MakeFlag  StandardCost  ListPrice  SubCategoryID
# 285         1      294.5797     539.99              1
# 286         1      294.5797     539.99              1
# ...

# %%
#como retornar informações estatisticas dos nossos dados
df.describe()
# Out:
#         ProductID    MakeFlag  StandardCost    ListPrice  SubCategoryID
# count  295.000000  295.000000    295.000000   295.000000     295.000000
# mean   851.915254    0.718644    438.220347   744.595220      12.294915
# std     85.462186    0.450425    534.895607   892.563172       9.860135
# min    680.000000    0.000000      0.856500     2.290000       1.000000
# 25%    778.500000    0.000000     35.959600    66.745000       2.000000
# 50%    852.000000    1.000000    199.851900   337.220000      12.000000
# 75%    925.500000    1.000000    650.418250  1100.240000      17.000000
# max    999.000000    1.000000   2171.294200  3578.270000      37.000000

# %%
#como filtrar os dados, primeiro é necessário filtrar quais são os itens unicos.
df["SubCategoryID"].unique()
# Out:
# array([14, 31, 23, 19, 21, 12,  2,  1, 10, 11,  4, 17, 22, 35, 34, 36, 33,
#        24, 18, 20, 25, 28, 37, 26, 29, 30, 27, 32, 16,  9,  6, 15, 13,  8,
#         7,  3,  5])

# %%
#Filtrando os dados de uma subcategoria especifica
subcat8 = df.loc[df["SubCategoryID"] == 8]
subcat8.head()
# Out:
#      ProductID ProductNumber  ProductName    ModelName  MakeFlag  \
# 244        949       CS-4759  LL Crankset  LL Crankset         1
# 245        950       CS-6583  ML Crankset  ML Crankset         1
# 246        951       CS-9183  HL Crankset  HL Crankset         1
#
#      StandardCost  ListPrice  SubCategoryID
# 244       77.9176     175.49              8
# 245      113.8816     256.49              8
# 246      179.8156     404.99              8

# %%
subcat8["SubCategoryID"].unique()
# Out:
# array([8])

# %%
#como fazer agrupamento de dados, neste exemplos vou verificar quantos produtos estão listados na sub categoria igual 8
df.groupby("SubCategoryID")["ProductName"].nunique()
# Out:
# SubCategoryID
# 1     32
# 2     43
# 3     22
# 4      8
# 5      3
# 6      2
# 7      1
# 8      3
# 9      2
# 10     3
# 11     3
# 12    28
# 13     7
# 14    33
# 15     9
# 16    18
# 17    14
# 18     3
# 19     1
# 20     6
# 21     8
# 22     7
# 23     4
# 24     3
# 25     3
# 26     1
# 27     1
# 28     3
# 29     1
# 30     1
# 31     3
# 32     1
# 33     3
# 34     1
# 35     1
# 36     2
# 37    11
# Name: ProductName, dtype: int64

# %%
#como saber a média
df["ListPrice"].mean()
# Out:
# 744.5952203389829

# %%
#realizar soma
df['StandardCost'].sum()
# Out:
# 129275.0025

# %%
#Alterando o tipo de dado da coluna
df["SubCategoryID"] = df["SubCategoryID"].astype("object")
df.dtypes
# Out:
# ProductID          int64
# ProductNumber     object
# ProductName       object
# ModelName         object
# MakeFlag           int64
# StandardCost     float64
# ListPrice        float64
# SubCategoryID     object
# dtype: object

# %%
#consultando para saber se existe algum valor nulo ou faltando
df.isnull().sum()
# Out:
# ProductID        0
# ProductNumber    0
# ProductName      0
# ModelName        0
# MakeFlag         0
# StandardCost     0
# ListPrice        0
# SubCategoryID    0
# dtype: int64

# %%
#caso tenha algum valor nulo ou faltando você pode substituir os valores nulos por zero ou pela média, mas se necessário você também pode apagar.
#para substituir pela média basta usar: df["nome da coluna"].fillna(df["nome da coluna"].mean(), inplace=True)
#para substituir por 0: df["nome da coluna"].fillna(0, inplace=true)
#para apagar: df.dropna(inplace = True)

# %%
#como criar uma nova coluna
df["receita"] = df["ListPrice"].mul(df["SubCategoryID"])
df.head()
# Out:
#    ProductID ProductNumber                ProductName            ModelName  \
# 0        680    FR-R92B-58  HL Road Frame - Black, 58        HL Road Frame
# 1        706    FR-R92R-58    HL Road Frame - Red, 58        HL Road Frame
# 2        707     HL-U509-R      Sport-100 Helmet, Red            Sport-100
# 3        708       HL-U509    Sport-100 Helmet, Black            Sport-100
# 4        709     SO-B909-M     Mountain Bike Socks, M  Mountain Bike Socks
#
#    MakeFlag  StandardCost  ListPrice SubCategoryID  receita
# 0         1     1059.3100    1431.50            14  20041.0
# 1         1     1059.3100    1431.50            14  20041.0
# 2         0       13.0863      34.99            31  1084.69
# 3         0       13.0863      34.99            31  1084.69
# 4         0        3.3963       9.50            23    218.5

# %%
df["qtdvendas"] = df["receita"] / df["ListPrice"]
df.head()
# Out:
#    ProductID ProductNumber                ProductName            ModelName  \
# 0        680    FR-R92B-58  HL Road Frame - Black, 58        HL Road Frame
# 1        706    FR-R92R-58    HL Road Frame - Red, 58        HL Road Frame
# 2        707     HL-U509-R      Sport-100 Helmet, Red            Sport-100
# 3        708       HL-U509    Sport-100 Helmet, Black            Sport-100
# 4        709     SO-B909-M     Mountain Bike Socks, M  Mountain Bike Socks
#
#    MakeFlag  StandardCost  ListPrice SubCategoryID  receita qtdvendas
# 0         1     1059.3100    1431.50            14  20041.0      14.0
# 1         1     1059.3100    1431.50            14  20041.0      14.0
# 2         0       13.0863      34.99            31  1084.69      31.0
# 3         0       13.0863      34.99            31  1084.69      31.0
# 4         0        3.3963       9.50            23    218.5      23.0

# %%
#como saber qual é o maior resultado de algo
df["receita"].max()
# Out:
# 20041.0

# %%
#como saber qual é o menor resultado de algo
df["receita"].min()
# Out:
# 84.73

# %%
#transformando os valores em int
df["receita"] = df["receita"].astype("int64")
df["qtdvendas"] = df["qtdvendas"].astype("int64")
df.dtypes
# Out:
# ProductID          int64
# ProductNumber     object
# ProductName       object
# ModelName         object
# MakeFlag           int64
# StandardCost     float64
# ListPrice        float64
# SubCategoryID     object
# receita            int64
# qtdvendas          int64
# dtype: object

# %%
#retorna o top 3 maior
df.nlargest(3,"receita")
# Out:
#     ProductID ProductNumber                ProductName      ModelName  \
# 0         680    FR-R92B-58  HL Road Frame - Black, 58  HL Road Frame
# 1         706    FR-R92R-58    HL Road Frame - Red, 58  HL Road Frame
# 12        717    FR-R92R-62    HL Road Frame - Red, 62  HL Road Frame
#
#     MakeFlag  StandardCost  ListPrice SubCategoryID  receita  qtdvendas
# 0          1     1059.3100     1431.5            14    20041         14
# 1          1     1059.3100     1431.5            14    20041         14
# 12         1      868.6342     1431.5            14    20041         14

# %%
#retorna o top 3 menor
df.nsmallest(3, "receita")
# Out:
#      ProductID ProductNumber            ProductName     ModelName  MakeFlag  \
# 168        873       PK-7098    Patch Kit/8 Patches     Patch kit         0
# 165        870       WB-H098  Water Bottle - 30 oz.  Water Bottle         0
# 247        952       CH-0234                  Chain         Chain         0
#
#      StandardCost  ListPrice SubCategoryID  receita  qtdvendas
# 168        0.8565       2.29            37       84         37
# 165        1.8663       4.99            28      139         28
# 247        8.9866      20.24             7      141          6

# %%
#saber qual foi os produtos que mais venderam
df.groupby("SubCategoryID")["receita"].sum()
# Out:
# SubCategoryID
# 1      53838
# 2     137343
# 3      94062
# 4       2362
# 5       1382
# 6       1278
# 7        141
# 8       6693
# 9       1916
# 10      5530
# 11      2873
# 12    227886
# 13      5822
# 14    360373
# 15      5346
# 16    181836
# 17     52575
# 18      4857
# 19       170
# 20      3744
# 21      8728
# 22      9893
# 23       848
# 24      5397
# 25      4761
# 26      3120
# 27      4293
# 28       669
# 29       230
# 30       659
# 31      3252
# 32      1759
# 33      3099
# 34       850
# 35      4375
# 36      1618
# 37      7924
# Name: receita, dtype: int64

# %%
#ordenando do maior para o menor
df.sort_values("receita", ascending=False).head(20)
# Out:
#      ProductID ProductNumber                     ProductName  \
# 0          680    FR-R92B-58       HL Road Frame - Black, 58
# 12         717    FR-R92R-62         HL Road Frame - Red, 62
# 1          706    FR-R92R-58         HL Road Frame - Red, 58
# 135        840    FR-R92B-52       HL Road Frame - Black, 52
# 134        839    FR-R92B-48       HL Road Frame - Black, 48
# 132        837    FR-R92B-62       HL Road Frame - Black, 62
# 16         721    FR-R92R-56         HL Road Frame - Red, 56
# 15         720    FR-R92R-52         HL Road Frame - Red, 52
# 14         719    FR-R92R-48         HL Road Frame - Red, 48
# 13         718    FR-R92R-44         HL Road Frame - Red, 44
# 133        838    FR-R92B-44       HL Road Frame - Black, 44
# 34         739    FR-M94S-42  HL Mountain Frame - Silver, 42
# 35         740    FR-M94S-44  HL Mountain Frame - Silver, 44
# 36         741    FR-M94S-52  HL Mountain Frame - Silver, 48
# ...

# %%
df["SubCategoryID"].value_counts(ascending=False)
# Out:
# 2     43
# 14    33
# 1     32
# 12    28
# 3     22
# 16    18
# 17    14
# 37    11
# 15     9
# 21     8
# 4      8
# 22     7
# 13     7
# 20     6
# 23     4
# 8      3
# 28     3
# 25     3
# 18     3
# 31     3
# 24     3
# 10     3
# 11     3
# 5      3
# 33     3
# 9      2
# 6      2
# 36     2
# 29     1
# 30     1
# 27     1
# 32     1
# 26     1
# 35     1
# 7      1
# 19     1
# 34     1
# Name: SubCategoryID, dtype: int64

# %%
#criando um grafico de barras
df["SubCategoryID"].value_counts(ascending=True).plot.barh();
